# %% [markdown]
# ### Q1. Take two numbers as input and handle ZeroDivisionError when dividing them.

# %%
# Your Answer Here

# %% [markdown]
# ### Q2. Take user input and convert it to an integer. Handle invalid input.

# %%
# Your Answer Here

# %% [markdown]
# ### Q3. Open a file named 'data.txt' and print its contents. Handle file not found error.

# %%
# Your Answer Here

# %% [markdown]
# ### Q4. Access an element from a list using user-provided index. Handle IndexError.

# %%
# Your Answer Here

# %% [markdown]
# ### Q5. Handle multiple exceptions: division by zero and invalid integer input.

# %%
# Your Answer Here

# %% [markdown]
# ### Q6. Write a program that always prints 'Execution completed' whether exception occurs or not.

# %%
# Your Answer Here

# %% [markdown]
# ### Q7. Ask user for age. If age < 18, raise ValueError.

# %%
# Your Answer Here

# %% [markdown]
# ### Q8. Create a custom exception 'NegativeNumberError'. Raise it for negative input.

# %%
# Your Answer Here

# %% [markdown]
# ### Q9. Write a function that divides two numbers and re-raises exception after printing custom message.

# %%
# Your Answer Here

# %% [markdown]
# ### Q10. Safely convert a list of values to integers. Skip invalid values.

# %%
# Your Answer Here

# %% [markdown]
# ### Q11. Handle KeyError when accessing dictionary values.

# %%
# Your Answer Here

# %% [markdown]
# ### Q12. Demonstrate nested try blocks.

# %%
# Your Answer Here

# %% [markdown]
# ### Q13. Validate a password (min 8 characters, must contain a digit). Raise exceptions if invalid.

# %%
# Your Answer Here

# %% [markdown]
# ### Q14. Handle exceptions while writing to a file.

# %%
# Your Answer Here

# %% [markdown]
# ### Q15. Write a decorator that catches any exception inside a function and prints error message.

# %%
# Your Answer Here

# %% [markdown]
# ### Q16. Process a list of numbers and safely perform division (ignore errors).

# %%
# Your Answer Here

# %% [markdown]
# ### Q17. Create a custom exception hierarchy for a banking system.

# %%
# Your Answer Here

# %% [markdown]
# ### Q18. Retry a function 3 times if it raises an exception.

# %%
# Your Answer Here

# %% [markdown]
# ### Q19. Create a context manager to safely handle file operations.

# %%
# Your Answer Here

# %% [markdown]
# ### Q20. Build a login system allowing only 3 attempts. Raise exceptions for wrong username or password.

# %%
# Your Answer Here
