# %% [markdown]
# # Python Practice Notebook: Data Types and Typecasting
# This notebook contains 30 beginner-level questions focusing on Python's built-in types (`int`, `float`, `str`) and typecasting between them.

# %% [markdown]
# ## Data Types

# %% [markdown]
# **Q1.**

# %%
# What is the data type of x?
x = 100
# Out:
# <class 'int'>

# %% [markdown]
# **Q2.**

# %%
# What is the data type of y?
y = 45.6

# Your answer here

# %% [markdown]
# **Q3.**

# %%
# What is the data type of z?
z = "Hello"

# Your answer here

# %% [markdown]
# **Q4.**

# %%
# Use type() to check the data type of x
x = "123"

# Your answer here

# %% [markdown]
# **Q5.**

# %%
# Use type() to check the data type of a float value
y = 12.34

# Your answer here

# %% [markdown]
# **Q6.**

# %%
# Use type() to check the data type of an integer
z = 99

# Your answer here

# %% [markdown]
# **Q7.**

# %%
# What is the data type of "100"?

# Your answer here

# %% [markdown]
# **Q8.**

# %%
# What is the data type of 100.0?

# Your answer here

# %% [markdown]
# **Q9.**

# %%
# What is the data type of 100?

# Your answer here

# %% [markdown]
# **Q10.**

# %%
# What is the data type of "Python"?

# Your answer here

# %% [markdown]
# **Q11.**

# %%
# What is the data type of "3.14"?

# Your answer here

# %% [markdown]
# **Q12.**

# %%
# What is the data type of the result of 10 / 2?

# Your answer here

# %% [markdown]
# **Q13.**

# %%
# What is the data type of the result of 10 + 2?

# Your answer here

# %% [markdown]
# **Q14.**

# %%
# What is the data type of ""?

# Your answer here

# %% [markdown]
# **Q15.**

# %%
# What is the data type of 0.0?

# Your answer here

# %% [markdown]
# ## Typecasting

# %% [markdown]
# **Q1.**

# %%
# Convert x = "5" into an integer and add 3
x = "5"

# Your answer here

# %% [markdown]
# **Q2.**

# %%
# Convert x = 10 into float
x = 10

# Your answer here

# %% [markdown]
# **Q3.**

# %%
# Convert x = 7.89 into int
x = 7.89

# Your answer here

# %% [markdown]
# **Q4.**

# %%
# Convert x = 15 into string and concat with text
x = 15

# Your answer here

# %% [markdown]
# **Q5.**

# %%
# Convert string "3.14" into float
x = "3.14"

# Your answer here

# %% [markdown]
# **Q6.**

# %%
# Convert string "100" into int and multiply by 2
x = "100"

# Your answer here

# %% [markdown]
# **Q7.**

# %%
# Convert float 99.99 into string and join with text
x = 99.99

# Your answer here

# %% [markdown]
# **Q8.**

# %%
# Convert int to float and add to another float
a = 5
b = 2.5

# Your answer here

# %% [markdown]
# **Q9.**

# %%
# Add two string numbers after converting to int
a = "8"
b = "12"

# Your answer here

# %% [markdown]
# **Q10.**

# %%
# Subtract int from a string number after conversion
x = "20"

# Your answer here

# %% [markdown]
# **Q11.**

# %%
# Multiply int and float after typecasting
x = 4
y = 2.5

# Your answer here

# %% [markdown]
# **Q12.**

# %%
# Convert number 123 to string and join with "Value: "
num = 123

# Your answer here

# %% [markdown]
# **Q13.**

# %%
# Convert a = "100", b = 50 to int and sum
a = "100"
b = 50

# Your answer here

# %% [markdown]
# **Q14.**

# %%
# Try casting "abc" to int (expect an error)
# print(int("abc"))

# Your answer here

# %% [markdown]
# **Q15.**

# %%
# Convert int to string and concat with label
age = 25

# Your answer here
