# %% [markdown]
# ### Q1. Create a list of numbers from 1 to 10 using list comprehension.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q2. Create a list of squares from 1 to 10 using list comprehension.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q3. Create a list of even numbers from 1 to 20 using list comprehension.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q4. Create a list of odd numbers from 1 to 20 using list comprehension.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q5. Create a list of numbers divisible by 3 from 1 to 30.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q6. Create a list of characters from the string 'python'.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q7. Create a list of lengths of each word in a list of words.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q8. Create a list of numbers greater than 10 from a given list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q9. Create a list of uppercase characters from a string.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q10. Create a list of lowercase characters from a string.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q11. Create a list by adding 5 to each element in a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q12. Create a list of squares of even numbers from 1 to 10.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q13. Create a list of first letters from a list of names.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q14. Create a list of numbers multiplied by 2 if number is even.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q15. Create a list of vowels from a string.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q16. Create a list of numbers excluding multiples of 5.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q17. Create a list of word lengths for words longer than 3 characters.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q18. Create a list of reversed strings from a list of strings.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q19. Create a list of positive numbers from a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q20. Create a list of numbers as strings from 1 to 10.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q21. Create a dictionary with numbers 1 to 5 as keys and their squares as values.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q22. Create a dictionary from two lists using dictionary comprehension.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q23. Create a dictionary with numbers 1 to 10 as keys and 'even' or 'odd' as values.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q24. Create a dictionary of characters and their ASCII values from a string.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q25. Create a dictionary with words as keys and their lengths as values.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q26. Create a dictionary with numbers as keys and their cubes as values.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q27. Create a dictionary by filtering even numbers from a given dictionary.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q28. Create a dictionary by swapping keys and values.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q29. Create a dictionary with numbers 1 to 10 and only include even numbers.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q30. Create a dictionary of uppercase characters from a string.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q31. Create a dictionary of lowercase characters from a string.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q32. Create a dictionary mapping numbers to True if even, else False.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q33. Create a dictionary of word frequencies from a list of words.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q34. Create a dictionary mapping characters to their frequency in a string.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q35. Create a dictionary with numbers as keys and double their value.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q36. Create a dictionary excluding items where value is less than 10.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q37. Create a dictionary with index as key and element as value from a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q38. Create a dictionary of squares only for odd numbers from 1 to 10.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q39. Create a dictionary mapping words to their first character.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q40. Create a dictionary mapping numbers to their string representation.
#
# **Answer:**

# %%
# Write your answer here
