# %% [markdown]
# # LIST QUESTION -----------------------------------------

# %% [markdown]
# ### Q1. Create a list with numbers 1 to 5 and print it.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q2. Find the length of a given list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q3. Add an element 10 to the end of a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q4. Insert 99 at index 2 in a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q5. Remove value 5 from a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q6. Remove the last element from a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q7. Count occurrences of an element using count().
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q8. Sort a list in ascending order.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q9. Sort a list in descending order.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q10. Reverse a list without using slicing().
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q11. Copy a list into another list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q12. Clear all elements from a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q13. Find the maximum value in a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q14. Find the minimum value in a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q15. Find the sum of all elements in a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q16. Create a list of squares from 1 to 5.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q17. Check if 10 exists in a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q18. Merge two lists into one.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q19. Create a list from the string 'python'.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q20. Convert a list [1,2,3] into a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q21. Remove duplicates from a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q22. Find even numbers from a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q23. Find odd numbers from a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q24. Replace all 0 with 1 in a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q25. Print each element using a for loop.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q26. Create an empty list and add 3 elements.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q27. Find the second largest element in a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q28. Split a list into two halves.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q29. Create a nested list and access an inner value.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q30. Find common elements between two lists.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# # TUPLE QUESTION -----------------------------------------

# %% [markdown]
# ### Q31. Create a tuple with numbers 1 to 5.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q32. Find the length of a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q33. Access the first element of a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q34. Access the last element of a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q35. Find the index of element 4 in a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q36. Count how many times 2 appears in a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q37. Convert a tuple into a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q38. Convert a list into a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q39. Check if 10 exists in a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q40. Find the maximum element in a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q41. Find the minimum element in a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q42. Find the sum of elements in a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q43. Create a single-value tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q44. Unpack a tuple into variables.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q45. Join two tuples.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q46. Repeat a tuple 3 times.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q47. Slice a tuple from index 1 to 3.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q48. Create a tuple from a string.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q49. Loop through a tuple and print values.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q50. Find even numbers from a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q51. Find odd numbers from a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q52. Reverse a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q53. Create a nested tuple and access inner value.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q54. Delete a tuple variable.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q55. Compare two tuples.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q56. Sort a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q57. Find the second smallest element in a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q58. Create a tuple of squares from 1 to 5.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q59. Check if all elements are positive.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q60. Find common elements between two tuples.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# # SET QUESTION -----------------------------------------

# %% [markdown]
# ### Q61. Create a set with numbers 1 to 5.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q62. Add an element 10 to a set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q63. Remove element 3 from a set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q64. Discard element 100 from a set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q65. Find the length of a set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q66. Check if 7 exists in a set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q67. Create a set from a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q68. Remove duplicates from a list using set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q69. Find the union of two sets.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q70. Find the intersection of two sets.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q71. Find the difference between two sets.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q72. Find the symmetric difference of two sets.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q73. Copy a set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q74. Clear all elements from a set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q75. Find the maximum value in a set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q76. Find the minimum value in a set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q77. Find the sum of elements in a set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q78. Loop through a set and print values.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q79. Check if one set is a subset of another.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q80. Check if one set is a superset of another.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q81. Create an empty set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q82. Convert a set into a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q83. Convert a set into a tuple.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q84. Remove a random element from a set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q85. Compare two sets for equality.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q86. Add multiple elements to a set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q87. Find common elements between two lists using set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q88. Check if two sets are disjoint.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q89. Create a frozen set.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q90. Find elements present in set A but not in set B.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# # DICTIONARY QUESTION -----------------------------------------

# %% [markdown]
# ### Q91. Create a dictionary with keys id, name, and age.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q92. Access the value using key 'name'.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q93. Add a new key 'salary' to the dictionary.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q94. Update the value of key 'age'.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q95. Remove key 'age' from the dictionary.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q96. Get all keys from the dictionary.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q97. Get all values from the dictionary.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q98. Get all key-value pairs from the dictionary.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q99. Check if key 'id' exists in the dictionary.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q100. Find the length of the dictionary.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q101. Copy a dictionary.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q102. Clear all elements from the dictionary.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q103. Create a dictionary from two lists.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q104. Create a dictionary using fromkeys().
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q105. Loop through keys and print values.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q106. Loop through items and print key and value.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q107. Get value of a key safely using get().
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q108. Remove the last inserted item.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q109. Merge two dictionaries.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q110. Find the sum of all values in a dictionary.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q111. Find the key with maximum value.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q112. Find the key with minimum value.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q113. Sort a dictionary by keys.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q114. Sort a dictionary by values.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q115. Convert dictionary keys into a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q116. Convert dictionary values into a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q117. Count frequency of characters in a string.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q118. Count frequency of elements in a list.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q119. Swap keys and values in a dictionary.
#
# **Answer:**

# %%
# Write your answer here

# %% [markdown]
# ### Q120. Create a nested dictionary and access an inner value.
#
# **Answer:**

# %%
# Write your answer here
