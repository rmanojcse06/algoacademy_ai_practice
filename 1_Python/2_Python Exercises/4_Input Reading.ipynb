# %% [markdown]
# # Part 1: Beginner-Friendly Input Reading

# %% [markdown]
# **Question 1:** Ask the user to enter a number and print it.

# %%
# Your answer here

# %% [markdown]
# **Question 2:** Ask for two numbers and print their sum.

# %%
# Your answer here

# %% [markdown]
# **Question 3:** Ask for two numbers and print their difference.

# %%
# Your answer here

# %% [markdown]
# **Question 4:** Ask for two numbers and print their product.

# %%
# Your answer here

# %% [markdown]
# **Question 5:** Ask for two numbers and print their quotient (division).

# %%
# Your answer here

# %% [markdown]
# **Question 6:** Ask for a number and print its square.

# %%
# Your answer here

# %% [markdown]
# **Question 7:** Ask for a number and print its cube.

# %%
# Your answer here

# %% [markdown]
# **Question 8:** Ask for two numbers and print the larger one.

# %%
# Your answer here

# %% [markdown]
# **Question 9:** Ask for two numbers and print the smaller one.

# %%
# Your answer here

# %% [markdown]
# **Question 10:** Ask for a number and print whether it is even.

# %%
# Your answer here

# %% [markdown]
# **Question 11:** Ask for a number and print whether it is odd.

# %%
# Your answer here

# %% [markdown]
# **Question 12:** Ask for a number and print double its value.

# %%
# Your answer here

# %% [markdown]
# **Question 13:** Ask for three numbers and print their sum.

# %%
# Your answer here

# %% [markdown]
# **Question 14:** Ask for three numbers and print their average.

# %%
# Your answer here

# %% [markdown]
# **Question 15:** Ask for a number and print the next number (number + 1).

# %%
# Your answer here

# %% [markdown]
# **Question 16:** Ask for a number and print the previous number (number - 1).

# %%
# Your answer here

# %% [markdown]
# **Question 17:** Ask for two numbers and print the remainder when the first is divided by the second.

# %%
# Your answer here

# %% [markdown]
# **Question 18:** Ask for two numbers and print the result of raising the first to the power of the second.

# %%
# Your answer here

# %% [markdown]
# **Question 19:** Ask for a number and print whether it is positive.

# %%
# Your answer here

# %% [markdown]
# **Question 20:** Ask for a number and print whether it is negative.

# %%
# Your answer here
