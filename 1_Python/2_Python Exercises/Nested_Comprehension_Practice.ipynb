# %% [markdown]
# # Nested List & Dictionary Comprehension Practice
#
# 40 Coding Questions

# %% [markdown]
# ## 🔵 Nested List Comprehension (1–20)

# %% [markdown]
# ### Q1. Create a 3×3 matrix filled with numbers 1–9.

# %%
# Your Answer Here

# %% [markdown]
# ### Q2. Create a 4×4 matrix filled with zeros.

# %%
# Your Answer Here

# %% [markdown]
# ### Q3. Flatten this matrix: matrix = [[1,2],[3,4],[5,6]]

# %%
# Your Answer Here

# %% [markdown]
# ### Q4. Extract only even numbers from a 3×3 matrix.

# %%
# Your Answer Here

# %% [markdown]
# ### Q5. Extract only odd numbers from a 3×3 matrix.

# %%
# Your Answer Here

# %% [markdown]
# ### Q6. Create a multiplication table (1–5).

# %%
# Your Answer Here

# %% [markdown]
# ### Q7. Transpose a 3×3 matrix.

# %%
# Your Answer Here

# %% [markdown]
# ### Q8. Create a 5×5 identity matrix.

# %%
# Your Answer Here

# %% [markdown]
# ### Q9. Replace negative numbers with 0 in a 2D list.

# %%
# Your Answer Here

# %% [markdown]
# ### Q10. Generate coordinate pairs (x,y) where x=1–3 and y=1–3.

# %%
# Your Answer Here

# %% [markdown]
# ### Q11. Create a list of squares for numbers 1–10 (only even numbers).

# %%
# Your Answer Here

# %% [markdown]
# ### Q12. From list of words, create list of character lists.

# %%
# Your Answer Here

# %% [markdown]
# ### Q13. From nested word list, create list of word lengths.

# %%
# Your Answer Here

# %% [markdown]
# ### Q14. From 2D list, extract elements greater than 5.

# %%
# Your Answer Here

# %% [markdown]
# ### Q15. Create a 3×3 matrix where value = row_index + column_index.

# %%
# Your Answer Here

# %% [markdown]
# ### Q16. Create nested list of cubes for numbers 1–4.

# %%
# Your Answer Here

# %% [markdown]
# ### Q17. Generate list of (x,y) where x < y and x,y in range(5).

# %%
# Your Answer Here

# %% [markdown]
# ### Q18. From 2D list, remove all zeros.

# %%
# Your Answer Here

# %% [markdown]
# ### Q19. Create 4×4 matrix filled with multiplication of row * column index.

# %%
# Your Answer Here

# %% [markdown]
# ### Q20. Convert 2D list of strings into uppercase.

# %%
# Your Answer Here

# %% [markdown]
# ## 🟢 Nested Dictionary Comprehension (21–40)

# %% [markdown]
# ### Q21. Create dictionary: number → square (1–10).

# %%
# Your Answer Here

# %% [markdown]
# ### Q22. Create dictionary: number → cube (1–5).

# %%
# Your Answer Here

# %% [markdown]
# ### Q23. Filter dictionary where value > 50.

# %%
# Your Answer Here

# %% [markdown]
# ### Q24. Invert a dictionary.

# %%
# Your Answer Here

# %% [markdown]
# ### Q25. Create nested dictionary: Keys 1–3, Values: square dictionary 1–3.

# %%
# Your Answer Here

# %% [markdown]
# ### Q26. Create multiplication table dictionary (1–3).

# %%
# Your Answer Here

# %% [markdown]
# ### Q27. Create dictionary: word → length.

# %%
# Your Answer Here

# %% [markdown]
# ### Q28. Create dictionary: word → list of vowels.

# %%
# Your Answer Here

# %% [markdown]
# ### Q29. Create dictionary: number → list of even numbers less than it (1–5).

# %%
# Your Answer Here

# %% [markdown]
# ### Q30. From nested dictionary, extract only items where inner value > 10.

# %%
# Your Answer Here

# %% [markdown]
# ### Q31. Flatten nested dictionary into tuple keys.

# %%
# Your Answer Here

# %% [markdown]
# ### Q32. Create dictionary: number → factorial (1–5).

# %%
# Your Answer Here

# %% [markdown]
# ### Q33. Create dictionary: letter → ASCII value (a–e).

# %%
# Your Answer Here

# %% [markdown]
# ### Q34. Create nested dictionary where outer keys=1–3, inner keys=1–3, value=sum of keys.

# %%
# Your Answer Here

# %% [markdown]
# ### Q35. Create dictionary: number → list of its divisors.

# %%
# Your Answer Here

# %% [markdown]
# ### Q36. Filter nested dictionary where sum of inner values > 20.

# %%
# Your Answer Here

# %% [markdown]
# ### Q37. Create dictionary mapping number to list of squares less than 50.

# %%
# Your Answer Here

# %% [markdown]
# ### Q38. Create dictionary: word → frequency of each character (nested dict).

# %%
# Your Answer Here

# %% [markdown]
# ### Q39. Create dictionary where keys 1–4 and values are list of tuples (x,y) for y=1–3.

# %%
# Your Answer Here

# %% [markdown]
# ### Q40. Create nested dictionary representing chessboard coordinates (1–8, a–h).

# %%
# Your Answer Here
