# %% [markdown]
# ## Conditional Statements

# %% [markdown]
# **Q:** Write a Python program to check if a number is positive.

# %%
# Your answer here

# %% [markdown]
# **Q:** Write a program that checks if a number is even or odd.

# %%
# Your answer here

# %% [markdown]
# **Q:** Ask the user for their age. If it’s 18 or more, print 'You are an adult'.

# %%
# Your answer here

# %% [markdown]
# **Q:** Check if a number is divisible by 3 and 5.

# %%
# Your answer here

# %% [markdown]
# **Q:** Check if a given character is a vowel or consonant.

# %%
# Your answer here

# %% [markdown]
# **Q:** Write a program that prints the greater of two numbers.

# %%
# Your answer here

# %% [markdown]
# **Q:** Check if a number is between 1 and 100.

# %%
# Your answer here

# %% [markdown]
# **Q:** Check whether a year is a leap year.

# %%
# Your answer here

# %% [markdown]
# **Q:** Take a number input and print whether it's positive, negative, or zero.

# %%
# Your answer here

# %% [markdown]
# **Q:** Ask the user to enter a password. If correct, print 'Access granted', otherwise 'Access denied'.

# %%
# Your answer here

# %% [markdown]
# **Q:** Write a program to check if a number is a multiple of 4.

# %%
# Your answer here

# %% [markdown]
# **Q:** If a person’s salary is above 50000, apply a 10% tax, else 5%.

# %%
# Your answer here

# %% [markdown]
# **Q:** Write a program to check if a student passed (marks > 40).

# %%
# Your answer here

# %% [markdown]
# **Q:** Find the smallest among three numbers.

# %%
# Your answer here

# %% [markdown]
# **Q:** Ask user for temperature; if above 30°C, print 'Hot', else 'Moderate'.

# %%
# Your answer here

# %% [markdown]
# **Q:** Take a character input and check if it’s uppercase.

# %%
# Your answer here

# %% [markdown]
# **Q:** Ask the user to enter a number and print 'Odd', 'Even', or 'Zero'.

# %%
# Your answer here

# %% [markdown]
# **Q:** Check if a string is 'yes' or 'no' and print confirmation.

# %%
# Your answer here

# %% [markdown]
# **Q:** Ask the user for two numbers and check if they are equal.

# %%
# Your answer here

# %% [markdown]
# **Q:** Write a program to compare two strings and print if they are equal or not.

# %%
# Your answer here
