# %% [markdown]
# # MAP() Practice - 20 Questions

# %% [markdown]
# ### Q1. Square each number in a list.

# %%
# Write your answer here

# %% [markdown]
# ### Q2. Convert all names in a list to uppercase.

# %%
# Write your answer here

# %% [markdown]
# ### Q3. Add 5 to every number in a list.

# %%
# Write your answer here

# %% [markdown]
# ### Q4. Convert a list of string numbers to integers.

# %%
# Write your answer here

# %% [markdown]
# ### Q5. Find the length of each word in a list.

# %%
# Write your answer here

# %% [markdown]
# ### Q6. Multiply each number by 3.

# %%
# Write your answer here

# %% [markdown]
# ### Q7. Convert Celsius values to Fahrenheit.

# %%
# Write your answer here

# %% [markdown]
# ### Q8. Remove extra spaces from each string.

# %%
# Write your answer here

# %% [markdown]
# ### Q9. Get the first letter of each word.

# %%
# Write your answer here

# %% [markdown]
# ### Q10. Cube each number in a list.

# %%
# Write your answer here

# %% [markdown]
# ### Q11. Convert integers to strings.

# %%
# Write your answer here

# %% [markdown]
# ### Q12. Get absolute values of numbers.

# %%
# Write your answer here

# %% [markdown]
# ### Q13. Multiply two lists element-wise.

# %%
# Write your answer here

# %% [markdown]
# ### Q14. Add two lists element-wise.

# %%
# Write your answer here

# %% [markdown]
# ### Q15. Convert words to lowercase.

# %%
# Write your answer here

# %% [markdown]
# ### Q16. Multiply numbers by 100.

# %%
# Write your answer here

# %% [markdown]
# ### Q17. Get the last letter of each word.

# %%
# Write your answer here

# %% [markdown]
# ### Q18. Convert floats to integers.

# %%
# Write your answer here

# %% [markdown]
# ### Q19. Add 1 to each number.

# %%
# Write your answer here

# %% [markdown]
# ### Q20. Divide each number by 2.

# %%
# Write your answer here

# %% [markdown]
# # FILTER() Practice - 20 Questions

# %% [markdown]
# ### Q1. Get even numbers from a list.

# %%
# Write your answer here

# %% [markdown]
# ### Q2. Get odd numbers from a list.

# %%
# Write your answer here

# %% [markdown]
# ### Q3. Get numbers greater than 10.

# %%
# Write your answer here

# %% [markdown]
# ### Q4. Get words longer than 4 letters.

# %%
# Write your answer here

# %% [markdown]
# ### Q5. Get positive numbers.

# %%
# Write your answer here

# %% [markdown]
# ### Q6. Get negative numbers.

# %%
# Write your answer here

# %% [markdown]
# ### Q7. Get numbers divisible by 3.

# %%
# Write your answer here

# %% [markdown]
# ### Q8. Get names starting with 'S'.

# %%
# Write your answer here

# %% [markdown]
# ### Q9. Get numbers less than 50.

# %%
# Write your answer here

# %% [markdown]
# ### Q10. Get words containing letter 'a'.

# %%
# Write your answer here

# %% [markdown]
# ### Q11. Get numbers greater than 100.

# %%
# Write your answer here

# %% [markdown]
# ### Q12. Get multiples of 5.

# %%
# Write your answer here

# %% [markdown]
# ### Q13. Get words with exactly 3 letters.

# %%
# Write your answer here

# %% [markdown]
# ### Q14. Get numbers between 10 and 20.

# %%
# Write your answer here

# %% [markdown]
# ### Q15. Get strings with length greater than 2.

# %%
# Write your answer here

# %% [markdown]
# ### Q16. Get numbers not equal to 0.

# %%
# Write your answer here

# %% [markdown]
# ### Q17. Get numbers greater than 5.

# %%
# Write your answer here

# %% [markdown]
# ### Q18. Get names ending with 'n'.

# %%
# Write your answer here

# %% [markdown]
# ### Q19. Get numbers less than 0.

# %%
# Write your answer here

# %% [markdown]
# ### Q20. Get numbers divisible by both 2 and 3.

# %%
# Write your answer here

# %% [markdown]
# # ZIP() Practice - 20 Questions

# %% [markdown]
# ### Q1. Combine names and marks into pairs.

# %%
# Write your answer here

# %% [markdown]
# ### Q2. Combine two lists into pairs.

# %%
# Write your answer here

# %% [markdown]
# ### Q3. Create a dictionary from two lists.

# %%
# Write your answer here

# %% [markdown]
# ### Q4. Add two lists element-wise.

# %%
# Write your answer here

# %% [markdown]
# ### Q5. Multiply two lists element-wise.

# %%
# Write your answer here

# %% [markdown]
# ### Q6. Pair numbers with their squares.

# %%
# Write your answer here

# %% [markdown]
# ### Q7. Combine three lists together.

# %%
# Write your answer here

# %% [markdown]
# ### Q8. Print paired values from two lists.

# %%
# Write your answer here

# %% [markdown]
# ### Q9. Create a list of sums using zip.

# %%
# Write your answer here

# %% [markdown]
# ### Q10. Create a list of products using zip.

# %%
# Write your answer here

# %% [markdown]
# ### Q11. Create a dictionary of names and scores.

# %%
# Write your answer here

# %% [markdown]
# ### Q12. Combine letters and numbers.

# %%
# Write your answer here

# %% [markdown]
# ### Q13. Zip two lists and convert to list.

# %%
# Write your answer here

# %% [markdown]
# ### Q14. Unzip a list of tuples.

# %%
# Write your answer here

# %% [markdown]
# ### Q15. Pair words with their lengths.

# %%
# Write your answer here

# %% [markdown]
# ### Q16. Compare two lists element-wise.

# %%
# Write your answer here

# %% [markdown]
# ### Q17. Create list of tuples from two lists.

# %%
# Write your answer here

# %% [markdown]
# ### Q18. Find max of paired elements.

# %%
# Write your answer here

# %% [markdown]
# ### Q19. Pair index and value.

# %%
# Write your answer here

# %% [markdown]
# ### Q20. Create dictionary of items and prices.

# %%
# Write your answer here

# %% [markdown]
# # LAMBDA Practice - 20 Questions

# %% [markdown]
# ### Q1. Write a lambda to square a number.

# %%
# Write your answer here

# %% [markdown]
# ### Q2. Write a lambda to add two numbers.

# %%
# Write your answer here

# %% [markdown]
# ### Q3. Write a lambda to check if number is even.

# %%
# Write your answer here

# %% [markdown]
# ### Q4. Write a lambda to multiply two numbers.

# %%
# Write your answer here

# %% [markdown]
# ### Q5. Write a lambda to convert string to uppercase.

# %%
# Write your answer here

# %% [markdown]
# ### Q6. Write a lambda to subtract two numbers.

# %%
# Write your answer here

# %% [markdown]
# ### Q7. Write a lambda to return length of string.

# %%
# Write your answer here

# %% [markdown]
# ### Q8. Write a lambda to cube a number.

# %%
# Write your answer here

# %% [markdown]
# ### Q9. Write a lambda to check if number > 10.

# %%
# Write your answer here

# %% [markdown]
# ### Q10. Write a lambda to divide two numbers.

# %%
# Write your answer here

# %% [markdown]
# ### Q11. Write a lambda to get first letter of word.

# %%
# Write your answer here

# %% [markdown]
# ### Q12. Write a lambda to get last letter of word.

# %%
# Write your answer here

# %% [markdown]
# ### Q13. Write a lambda to double a number.

# %%
# Write your answer here

# %% [markdown]
# ### Q14. Write a lambda to return absolute value.

# %%
# Write your answer here

# %% [markdown]
# ### Q15. Write a lambda to check if string starts with 'A'.

# %%
# Write your answer here

# %% [markdown]
# ### Q16. Write a lambda to add 100 to a number.

# %%
# Write your answer here

# %% [markdown]
# ### Q17. Write a lambda to convert string to lowercase.

# %%
# Write your answer here

# %% [markdown]
# ### Q18. Write a lambda to check if number divisible by 5.

# %%
# Write your answer here

# %% [markdown]
# ### Q19. Write a lambda to multiply number by 10.

# %%
# Write your answer here

# %% [markdown]
# ### Q20. Write a lambda to return True if string length > 3.

# %%
# Write your answer here
